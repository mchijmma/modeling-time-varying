# %%
import IPython.display as ipd
import librosa

# %%
a, sr = librosa.load('x.wav')

# %%
ipd.Audio(a, rate = 44100)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
